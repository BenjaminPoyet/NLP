# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader>  d
# Download which package (l=list; x=cancel)?
#   Identifier>  all
# ...
#        |
#        | Downloading package abc to /home/jovyan/nltk_data...
#        |   Package abc is already up-to-date!
#        | Downloading package alpino to /home/jovyan/nltk_data...
#        |   Package alpino is already up-to-date!
#        | Downloading package biocreative_ppi to
#        |     /home/jovyan/nltk_data...
#        |   Package biocreative_ppi is already up-to-date!
#        | Downloading package brown to /home/jovyan/nltk_data...
#        |   Package brown is already up-to-date!
#        | Downloading package brown_tei to /home/jovyan/nltk_data...
#        |   Package brown_tei is already up-to-date!
# ...

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

#Tokenize words
data = "All work and no play makes jack a dull boy, all work and no play"
print(word_tokenize(data))
# Out:
# ['All', 'work', 'and', 'no', 'play', 'makes', 'jack', 'a', 'dull', 'boy', ',', 'all', 'work', 'and', 'no', 'play']

# %%
#Tokenize sentences
from nltk.tokenize import sent_tokenize, word_tokenize

data = "All work and no play makes jack dull boy. All work and no play makes jack a dull boy."
print(sent_tokenize(data))
# Out:
# ['All work and no play makes jack dull boy.', 'All work and no play makes jack a dull boy.']

# %%
#store sentence and sentences in arrays

from nltk.tokenize import sent_tokenize, word_tokenize
data = "All work and no play makes jack dull boy. All work and no play makes jack a dull boy."

phrases = sent_tokenize(data)
words = word_tokenize(data)

print(phrases)
print(words)
# Out:
# ['All work and no play makes jack dull boy.', 'All work and no play makes jack a dull boy.']
# ['All', 'work', 'and', 'no', 'play', 'makes', 'jack', 'dull', 'boy', '.', 'All', 'work', 'and', 'no', 'play', 'makes', 'jack', 'a', 'dull', 'boy', '.']

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

#apply the stop words
data = "All work and no play makes jack dull boy. All work and no play makes jack a dull boy."
stopWords = set(stopwords.words('english'))
words = word_tokenize(data)
wordsFiltered = []

for w in words:
    if w not in stopWords:
        wordsFiltered.append(w)

print(wordsFiltered)
# Out:
# ['All', 'work', 'play', 'makes', 'jack', 'dull', 'boy', '.', 'All', 'work', 'play', 'makes', 'jack', 'dull', 'boy', '.']

# %%
#get a set of English keywords
stopWords = set(stopwords.words('english'))
print(len(stopWords))
print(stopWords)
# Out:
# 179
# ...

# %%
#stemming = variation of the word
#let's define some variation of a word in an array
words = ["game","gaming","gamed","games"]
words
# Out:
# ['game', 'gaming', 'gamed', 'games']

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
#apply the PorterStemmer to find the word behind the stems
words = ["game","gaming","gamed","games"]
ps=PorterStemmer()
for word in words:
    print(ps.stem(word))
# Out:
# game
# game
# game
# game

# %%
sentence = "gaming, the gamers play games"
words = word_tokenize(sentence)

for word in words:
    print(word + ":" + ps.stem(word))
# Out:
# gaming:game
# ,:,
# the:the
# gamers:gamer
# play:play
# games:game

# %%
import nltk
from nltk.tokenize import PunktSentenceTokenizer

document = 'Whether you\'re new to programming or an experienced developer, it\'s easy to learn and use Python.'
sentences = nltk.sent_tokenize(document)   
for sent in sentences:
    print(nltk.pos_tag(nltk.word_tokenize(sent)))
# Out:
# [('Whether', 'IN'), ('you', 'PRP'), ("'re", 'VBP'), ('new', 'JJ'), ('to', 'TO'), ('programming', 'VBG'), ('or', 'CC'), ('an', 'DT'), ('experienced', 'JJ'), ('developer', 'NN'), (',', ','), ('it', 'PRP'), ("'s", 'VBZ'), ('easy', 'JJ'), ('to', 'TO'), ('learn', 'VB'), ('and', 'CC'), ('use', 'VB'), ('Python', 'NNP'), ('.', '.')]

# %%
from PIL import Image
import requests
from io import BytesIO

response = requests.get('https://pythonspot.com/wp-content/uploads/2016/08/nltk-speech-codes.png')
img = Image.open(BytesIO(response.content))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=826x274 at 0x7EFD6E1BB510>

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

document = 'Today the Netherlands celebrates King\'s Day. To honor this tradition, the Dutch embassy in San Francisco invited me to'
sentences = nltk.sent_tokenize(document)   

data = []
for sent in sentences:
    data = data + nltk.pos_tag(nltk.word_tokenize(sent))
   
for word in data: 
    if 'NNP' in word[1]: 
        print(word)
# Out:
# ('Netherlands', 'NNP')
# ('King', 'NNP')
# ('Day', 'NNP')
# ('San', 'NNP')
# ('Francisco', 'NNP')
